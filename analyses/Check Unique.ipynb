# %%
import pandas as pd
import numpy as np
import os

for i in os.listdir('../private/rows'):
    print i
    df = pd.read_csv('../private/rows/' + i)
    if df.shape[0] <= 1 or df.shape[1] <= 1:
        continue

    print '\n'.join(map(str, df[df.columns[1]].unique()))
# Out:
# class_attendance_2a.csv
# 1
# 3
# 4
# 2
# coop_salary_3.csv
# 3,600.00
# 6,500.00
# 3,828.00
# 13,100.00
# 4,167.00
# 3,813.00
# 8,515.00
# 4,000.00
# 8,500.00
# 6,100.00
# 9,000.00
# 8,000.00
# 3,360.00
# 8,384.00
# 7,500.00
# nan
# 6,000.00
# 4,096.00
# 8,220.00
# 4,160.00
# 6,720.00
# 4,200.00
# 4,560.00
# 3,700.00
# 3,000.00
# 2,000.00
# 2,070.00
# 6,250.00
# 2,400.00
# 4,800.00
# 5,500.00
# 4,500.00
# 4,400.00
# 5,000.00
# 3,500.00
# 2,200.00
# 4,960.00
# 2,700.00
# 3,216.00
# 4,250.00
# 13,000.00
# 3,100.00
# 2,080.00
# 7,050.00
# 5,538.00
# 4,333.00
# 3,050.00
# 5,895.00
# 2,960.00
# 10,349.00
# 7,180.00
# 1,100.00
# 3,680.00
# 9,500.00
# 3,520.00
# 3,200.00
# 2,560.00
# 6,060.00
# 8,900.00
# 6,080.00
# 2,500.00
# 7,245.00
# 7,360.00
# 6,933.33
# 2,760.00
# 9,825.00
# 3,472.00
# 8,850.00
# 3,336.66
# 3,840.00
# 3,539.20
# fav_course.csv
# SE 350
# ECE 454
# CS 241
# MATH 239
# CS 452
# CO 342
# CS 343
# SE 350, ECE 454
# CS 488
# nan
# CS 341
# SE 101
# CS 449
# CS 466
# ...
